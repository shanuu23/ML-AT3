# %% [markdown]
# # **EDA Notebook**

# %% [markdown]
# ---
# ## 0. Setup Environment

# %%
# DO NOT MODIFY THE CODE IN THIS CELL
# !pip install -q utstd

from utstd.folders import *
from utstd.ipyrenders import *

at = AtFolder(
    course_code=36106,
    assignment="AT3",
)
at.run()

import warnings
warnings.simplefilter(action='ignore')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 37.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# umap-learn 0.5.12 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# hdbscan 0.8.42 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Mounted at /content/gdrive
#
# You can now save your data files in: /content/gdrive/MyDrive/36106/assignment/AT3/data

# %% [markdown]
# ---
# ## Student Information

# %%
# <Student to fill this section>
group_name = "Group 20"
student_name = "Ratnadeep Patra"
student_id = "26294153"

# %%
# Do not modify this code
print_tile(size="h1", key='group_name', value=group_name)
# Out:
# <p style="color:grey">group_name</p><h1 font-size: 3em>Group 20</h1>

# %%
# Do not modify this code
print_tile(size="h1", key='student_name', value=student_name)
# Out:
# <p style="color:grey">student_name</p><h1 font-size: 3em>Ratnadeep Patra</h1>

# %%
# Do not modify this code
print_tile(size="h1", key='student_id', value=student_id)
# Out:
# <p style="color:grey">student_id</p><h1 font-size: 3em>26294153</h1>

# %% [markdown]
# ---
# ## 0. Python Packages

# %% [markdown]
# ### 0.a Install Additional Packages
#
# > If you are using additional packages, you need to install them here using the command: `! pip install <package_name>`

# %%
# <Student to fill this section>

# %% [markdown]
# ### 0.b Import Packages

# %%
# <Student to fill this section>
import pandas as pd
import altair as alt

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ---
# ## B. Data Understanding

# %%
# Do not modify this code
try:
  df = pd.read_csv(at.folder_path / "store.csv")
except Exception as e:
  print(e)

# %% [markdown]
# ### B.1 Explore Dataset

# %%
df.describe(include='all').T
# Out:
#                 count unique                                   top freq
# store_id          701    701  fb3f2681-31a3-4309-8654-088e5075dca7    1
# sales_person_id   701     13  28141e19-49e8-4090-9196-6e8f43b10de8   80
# name              701    699                 Sports Products Store    2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   store_id         701 non-null    object
#  1   sales_person_id  701 non-null    object
#  2   name             701 non-null    object
# dtypes: object(3)
# memory usage: 16.6+ KB

# %%
df.sample(5)
# Out:
#                                  store_id  \
# 115  0ab96857-8eac-4f03-a1f8-10e376814689
# 551  9a0ba015-80b1-4df5-a54a-58c3676f6149
# 303  552c7546-dc57-4509-b2d7-472f901fbf71
# 35   4ebf1c75-48ea-445c-8636-e8d98a6d537e
# 573  57333052-bffd-437b-b0e2-f27052e0e58f
#
#                           sales_person_id                                name
# 115  48505c49-f9c7-4476-a670-158f89c331a7                   Raw Materials Inc
# 551  27d62980-8d18-4170-95a5-7f7bb9cada5a                       Tire Exchange
# 303  28141e19-49e8-4090-9196-6e8f43b10de8            Tough and Reliable Parts
# 35   28141e19-49e8-4090-9196-6e8f43b10de8  Distinctive Cycles Sales & Service
# 573  48505c49-f9c7-4476-a670-158f89c331a7                 Some Discount Store

# %%
# <Student to fill this section>
dataset_insights = """
The dataset contains 701 entries and 3 columns: 'store_id', 'sales_person_id', and 'name'. All columns are of object (string) dtype and have no missing
values. The 'store_id' column has 701 unique values, indicating each record represents a distinct store. The 'sales_person_id' column has only 13 unique
values, suggesting that a small number of salespersons are responsible for a large number of stores. The 'name' column has 699 unique values, which implies
that some stores might share the same name but have different unique store IDs.
"""

# %%
# Do not modify this code
print_tile(size="h3", key='dataset_insights', value=dataset_insights)
# Out:
# <p style="color:grey">dataset_insights</p><h3 font-size: 3em>
# The dataset contains 701 entries and 3 columns: 'store_id', 'sales_person_id', and 'name'. All columns are of object (string) dtype and have no missing
# values. The 'store_id' column has 701 unique values, indicating each record represents a distinct store. The 'sales_person_id' column has only 13 unique
# values, suggesting that a small number of salespersons are responsible for a large number of stores. The 'name' column has 699 unique values, which implies
# that some stores might share the same name but have different unique store IDs.
# </h3>

# %% [markdown]
# ### B.2 Explore Feature of Interest `sales_person_id`

# %%
for csv_file in os.listdir(at.folder_path):
    if csv_file.endswith('.csv'):
        try:
            if 'sales_person_id' in pd.read_csv(at.folder_path / csv_file).columns:
                print(csv_file)
        except UnicodeDecodeError:
            print(f"Warning: Could not read {csv_file} with default encoding. Skipping or consider specifying encoding.")
        except Exception as e:
            print(f"Error reading {csv_file}: {e}")
# Out:
# sales_order_header.csv
# store.csv

# %%
df['sales_person_id'].value_counts(ascending=False)
# Out:
# sales_person_id
# 28141e19-49e8-4090-9196-6e8f43b10de8    80
# 59948fbd-99d9-43fd-b5ab-20614fc4193d    79
# 0e8f1395-12c4-4d5b-b2df-257bc78a9b29    77
# 0ca60d7b-b278-4a10-88c7-aa2c62611482    76
# 27d62980-8d18-4170-95a5-7f7bb9cada5a    74
# 3c91dda3-5a66-476e-b9d4-b686e959bda5    40
# 9787b7d5-2461-464d-9354-2da1defdb675    40
# 9737ee67-ea97-4ab7-9e6c-70f8878c6ab2    40
# f077eda9-c3db-4fde-81d2-e0f7ada08fcc    40
# 0445ab08-f703-4d2c-8ab3-fb7948bc1a48    40
# 16eb6889-25f7-475a-9eff-92024a00fde9    39
# e03321bf-f1d3-4324-9184-008d6fb535da    38
# 48505c49-f9c7-4476-a670-158f89c331a7    38
# Name: count, dtype: int64

# %%
(
    df['sales_person_id'].nunique(),
    df['sales_person_id'].value_counts().mean(),
    df['sales_person_id'].value_counts().max(),
    df['sales_person_id'].value_counts().min(),
)
# Out:
# (13, np.float64(53.92307692307692), 80, 38)

# %%
# <Student to fill this section>
feature_1_insights = """
The 'sales_person_id' feature indicates a highly concentrated distribution, with only 13 unique salespersons managing 701 stores. On average, each
salesperson is responsible for approximately 53.92 stores. The salesperson with the highest workload is assigned 80 stores, while the minimum is 38. This
suggests an organizational structure where a few sales personnel manage a significant number of retail locations. Further insights into the
'sales_person_id' can be gained from the 'sales_order_header.csv' file, which likely contains transaction-level data related to these salespersons.
"""

# %%
# Do not modify this code
print_tile(size="h3", key='feature_1_insights', value=feature_1_insights)
# Out:
# <p style="color:grey">feature_1_insights</p><h3 font-size: 3em>
# The 'sales_person_id' feature indicates a highly concentrated distribution, with only 13 unique salespersons managing 701 stores. On average, each
# salesperson is responsible for approximately 53.92 stores. The salesperson with the highest workload is assigned 80 stores, while the minimum is 38. This
# suggests an organizational structure where a few sales personnel manage a significant number of retail locations. Further insights into the
# 'sales_person_id' can be gained from the 'sales_order_header.csv' file, which likely contains transaction-level data related to these salespersons.
# </h3>
